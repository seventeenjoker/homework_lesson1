# %%
import pandas as pd

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
export_2015 = pd.read_excel('Russia-2015.xlsx', sheet_name='Partner')
export_2016 = pd.read_excel('Russia-2016.xlsx', sheet_name='Partner')

# %%
export_2015.head()
# Out:
#         Reporter Name Partner Name  Year Trade Flow  \
# 0  Russian Federation        Aruba  2015     Export
# 1  Russian Federation  Afghanistan  2015     Export
# 2  Russian Federation       Angola  2015     Export
# 3  Russian Federation      Anguila  2015     Export
# 4  Russian Federation      Albania  2015     Export
#
#    No Of exported HS6 digit Products  Export Share in Total Products (%)  \
# 0                                nan                                 nan
# 1                             183.00                                4.23
# 2                             286.00                                6.61
# 3                                nan                                 nan
# 4                              86.00                                1.99
#
#    Export (US$ Thousand)  Export Partner Share (%)
# 0                    nan                       nan
# 1              148012.80                      0.04
# 2              139394.17                      0.04
# 3                    nan                       nan
# 4               66986.54                      0.02

# %%
export_2016.head()
# Out:
#         Reporter Name Partner Name  Year Trade Flow  \
# 0  Russian Federation        Aruba  2016     Export
# 1  Russian Federation  Afghanistan  2016     Export
# 2  Russian Federation       Angola  2016     Export
# 3  Russian Federation      Albania  2016     Export
# 4  Russian Federation      Andorra  2016     Export
#
#    No Of exported HS6 digit Products  Export Share in Total Products (%)  \
# 0                               2.00                                0.05
# 1                             125.00                                2.87
# 2                             340.00                                7.82
# 3                              86.00                                1.98
# 4                              41.00                                0.94
#
#    Export (US$ Thousand)  Export Partner Share (%)
# 0               21610.42                      0.01
# 1              184160.51                      0.06
# 2              567915.73                      0.20
# 3               57932.40                      0.02
# 4                2363.46                      0.00

# %%
export = pd.concat([export_2015, export_2016])

# %%
export.sample(10)
# Out:
#           Reporter Name Partner Name  Year Trade Flow  \
# 211  Russian Federation       Turkey  2016     Export
# 86   Russian Federation    Greenland  2016     Export
# 104  Russian Federation        Japan  2015     Export
# 56   Russian Federation      Denmark  2015     Export
# 175  Russian Federation      Romania  2016     Export
# 34   Russian Federation     Botswana  2016     Export
# 217  Russian Federation   Uzbekistan  2015     Export
# 4    Russian Federation      Albania  2015     Export
# 215  Russian Federation      Uruguay  2015     Export
# 185  Russian Federation  El Salvador  2016     Export
#
#      No Of exported HS6 digit Products  Export Share in Total Products (%)  \
# 211                             957.00                               22.00
# 86                                1.00                                0.02
# 104                             682.00                               15.75
# 56                              380.00                                8.78
# 175                             761.00                               17.49
# 34                                8.00                                0.18
# 217                            2144.00                               49.52
# 4                                86.00                                1.99
# 215                             254.00                                5.87
# 185                              13.00                                0.30
#
#      Export (US$ Thousand)  Export Partner Share (%)
# 211            13698261.43                      4.80
# 86                   12.06                      0.00
# 104            14426352.10                      4.19
# 56              1790721.46                      0.52
# 175             1845485.34                      0.65
# 34                21248.74                      0.01
# 217             2221187.87                      0.65
# 4                 66986.54                      0.02
# 215               32073.90                      0.01
# 185                6896.17                      0.00

# %%
exclude = ['Europe & Central Asia', 'East Asia & Pacific', ' World', 'Unspecified', 'Middle East & North Africa']

# %%
export_filtered = export[-export['Partner Name'].isin(exclude)]

# %%
export_pivot = export_filtered.pivot_table(index=['Year', 'Partner Name'], values='Export (US$ Thousand)', aggfunc='sum')\
    .sort_values(['Year', 'Export (US$ Thousand)'], ascending=[True, False])

# %%
export_pivot[export_pivot.index.get_level_values('Year') == 2015]
# Out:
#                                      Export (US$ Thousand)
# Year Partner Name
# 2015 Netherlands                               40198496.43
#      China                                     28334954.57
#      Italy                                     16204284.05
#      Germany                                   15906242.25
#      Japan                                     14426352.10
# ...                                                    ...
#      Turks and Caicos Isl.                            0.00
#      Tuvalu                                           0.00
#      United States Minor Outlying I                   0.00
#      Vanuatu                                          0.00
#      Wallis and Futura Isl.                           0.00
#
# [226 rows x 1 columns]
